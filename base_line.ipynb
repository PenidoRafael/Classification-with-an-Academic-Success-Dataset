# %% [markdown]
# ## Base Line ##
# Este é apenas um modelo de base line. A performance dele deve servir como chão, um limite inferior, aos modelos subsequentes.

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline

# %%
sintetico = pd.read_csv('src/train/train.csv', index_col='id')
original = pd.read_csv('src/train/original.csv')
test = pd.read_csv('src/test/test.csv', index_col='id')

train = pd.concat([sintetico, original], ignore_index=True)

initial_features = list(test.columns)

# %%
train
# Out:
#        Marital status  Application mode  Application order  Course  \
# 0                   1                 1                  1    9238
# 1                   1                17                  1    9238
# 2                   1                17                  2    9254
# 3                   1                 1                  3    9500
# 4                   1                 1                  2    9500
# ...               ...               ...                ...     ...
# 80937               1                 1                  6    9773
# 80938               1                 1                  2    9773
# 80939               1                 1                  1    9500
# 80940               1                 1                  1    9147
# 80941               1                10                  1    9773
#
#        Daytime/evening attendance  Previous qualification  \
# 0                               1                       1
# 1                               1                       1
# 2                               1                       1
# 3                               1                       1
# 4                               1                       1
# ...                           ...                     ...
# 80937                           1                       1
# 80938                           1                       1
# 80939                           1                       1
# 80940                           1                       1
# 80941                           1                       1
#
#        Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                               126.0            1                       1
# 1                               125.0            1                      19
# 2                               137.0            1                       3
# 3                               131.0            1                      19
# 4                               132.0            1                      19
# ...                               ...          ...                     ...
# 80937                           125.0            1                       1
# 80938                           120.0          105                       1
# 80939                           154.0            1                      37
# 80940                           180.0            1                      37
# 80941                           152.0           22                      38
#
#        Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                          19  ...                                    0
# 1                          19  ...                                    0
# 2                          19  ...                                    0
# 3                           3  ...                                    0
# 4                          37  ...                                    0
# ...                       ...  ...                                  ...
# 80937                       1  ...                                    0
# 80938                       1  ...                                    0
# 80939                      37  ...                                    0
# 80940                      37  ...                                    0
# 80941                      37  ...                                    0
#
#        Curricular units 2nd sem (enrolled)  \
# 0                                        6
# 1                                        6
# 2                                        6
# 3                                        8
# 4                                        7
# ...                                    ...
# 80937                                    6
# 80938                                    6
# 80939                                    8
# 80940                                    5
# 80941                                    6
#
#        Curricular units 2nd sem (evaluations)  \
# 0                                           7
# 1                                           9
# 2                                           0
# 3                                          11
# 4                                          12
# ...                                       ...
# 80937                                       8
# 80938                                       6
# 80939                                       9
# 80940                                       6
# 80941                                       6
#
#        Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                        6                         12.428571
# 1                                        0                          0.000000
# 2                                        0                          0.000000
# 3                                        7                         12.820000
# 4                                        6                         12.933333
# ...                                    ...                               ...
# 80937                                    5                         12.666667
# 80938                                    2                         11.000000
# 80939                                    1                         13.500000
# 80940                                    5                         12.000000
# 80941                                    6                         13.000000
#
#        Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                                   0               11.1
# 1                                                   0               11.1
# 2                                                   0               16.2
# 3                                                   0               11.1
# 4                                                   0                7.6
# ...                                               ...                ...
# 80937                                               0               15.5
# 80938                                               0               11.1
# 80939                                               0               13.9
# 80940                                               0                9.4
# 80941                                               0               12.7
#
#        Inflation rate   GDP    Target
# 0                 0.6  2.02  Graduate
# 1                 0.6  2.02   Dropout
# 2                 0.3 -0.92   Dropout
# 3                 0.6  2.02  Enrolled
# 4                 2.6  0.32  Graduate
# ...               ...   ...       ...
# 80937             2.8 -4.06  Graduate
# 80938             0.6  2.02   Dropout
# 80939            -0.3  0.79   Dropout
# 80940            -0.8 -3.12  Graduate
# 80941             3.7 -1.70  Graduate
#
# [80942 rows x 37 columns]

# %%
cat_features = ['Marital status', 'Application mode', 'Course',
                'Previous qualification', 'Nacionality', "Mother's qualification", 
                "Father's qualification", "Mother's occupation",
                "Father's occupation"]

for feature in cat_features:
    for df in [train, test]:
        df[feature] = df[feature].astype('category')

# %%
label_encoder = LabelEncoder()

y = label_encoder.fit_transform(train['Target'])
X = train[initial_features]

# %%
#Pipeline para fazer o preprocessamento dos dados

preprocessor = ColumnTransformer(
    transformers=[
        # ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features),
    ])

# %%
#Pipeline para aplicar o preprocessamento e criar o modelo

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', XGBClassifier(random_state=42))
])

model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Marital status',
#                                                    'Application mode', 'Course',
#                                                    'Previous qualification',
#                                                    'Nacionality',
#                                                    "Mother's qualification",
#                                                    "Father's qualification",
#                                                    "Mother's occupation",
#                                                    "Father's occupation"])])),
#                 ('classifier',
#                  XGBClassifier(base_score=None, booster=None, callba...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None,
#                                objective='multi:softprob', ...))])

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Validação cruzada estratificada
scores = cross_val_score(model, X, y, cv=skf, scoring='accuracy')

print("Accuracy:", scores.mean())
# Out:
# Accuracy: 0.6399520031232768
